# %%
import numpy as np 
import pandas as pd

# %%
data_set=pd.read_csv("billionaire.csv")

# %%
data_set.head()
#to print first 4 rows 
#to print no of rows by giving number
# Out:
#    Unnamed: 0                          name   last_name  age gender  time  \
# 0         675  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M  2013
# 1         676  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M  2013
# 2         677  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M  2013
# 3         678  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M  2013
# 4         679  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M  2013
#
#             permanent_country       company main_industry  \
# 0  United Arab Emirates-Dubai  Mashreq Bank   Diversified
# 1  United Arab Emirates-Dubai  Mashreq Bank   Diversified
# 2  United Arab Emirates-Dubai  Mashreq Bank   Diversified
# 3  United Arab Emirates-Dubai  Mashreq Bank   Diversified
# 4  United Arab Emirates-Dubai  Mashreq Bank   Diversified
#
#   wealth_source_details             industry state headquarters countries  \
# 0           diversified  Diversified;Banking   NaN          NaN       are
# ...

# %%
data_set.columns
#to print columns
# Out:
# Index(['Unnamed: 0', 'name', 'last_name', 'age', 'gender', 'time',
#        'permanent_country', 'company', 'main_industry',
#        'wealth_source_details', 'industry', 'state', 'headquarters',
#        'countries', 'annual_income', 'daily_income', 'birth_year',
#        'name_cleaned'],
#       dtype='object')

# %%
data_set.dropna(thresh=2)
#non null values which are having less than 2 will drop
# Out:
#         Unnamed: 0                          name   last_name  age gender  \
# 0              675  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 1              676  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 2              677  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 3              678  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 4              679  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# ...            ...                           ...         ...  ...    ...
# 352364      358313            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352365      358314            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352366      358315            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352367      358316            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352368      358317            Zygmunt Solorz-Zak  Solorz-Zak   65      M
#
#         time           permanent_country         company  \
# ...

# %%
data_set.dropna()
#deletes the null value rows
# Out:
#         Unnamed: 0                          name  age  time  \
# 0              675  Abdulla bin Ahmad Al Ghurair   67  2013
# 1              676  Abdulla bin Ahmad Al Ghurair   67  2013
# 2              677  Abdulla bin Ahmad Al Ghurair   67  2013
# 3              678  Abdulla bin Ahmad Al Ghurair   67  2013
# 4              679  Abdulla bin Ahmad Al Ghurair   67  2013
# ...            ...                           ...  ...   ...
# 352364      358313            Zygmunt Solorz-Zak   65  2022
# 352365      358314            Zygmunt Solorz-Zak   65  2022
# 352366      358315            Zygmunt Solorz-Zak   65  2022
# 352367      358316            Zygmunt Solorz-Zak   65  2022
# 352368      358317            Zygmunt Solorz-Zak   65  2022
#
#                 main_industry countries  annual_income  daily_income  \
# 0                 Diversified       are       95604000        261928
# 1                 Diversified       are       95604000        399254
# ...

# %%
data_set.isnull()
#gives the true if there is null value in data set
# Out:
#         Unnamed: 0   name  last_name    age  gender   time  permanent_country  \
# 0            False  False      False  False   False  False              False
# 1            False  False      False  False   False  False              False
# 2            False  False      False  False   False  False              False
# 3            False  False      False  False   False  False              False
# 4            False  False      False  False   False  False              False
# ...            ...    ...        ...    ...     ...    ...                ...
# 352364       False  False      False  False   False  False              False
# 352365       False  False      False  False   False  False              False
# 352366       False  False      False  False   False  False              False
# 352367       False  False      False  False   False  False              False
# 352368       False  False      False  False   False  False              False
#
# ...

# %%
type(data_set) 
#prints the datatype of the dataset
# Out:
# pandas.core.frame.DataFrame

# %%
data_set['name'].nunique()
#gives us the total number of unique values in data set
# Out:
# 4976

# %%
data_set.dropna(axis=1)
#delete the columns in which null values are present
# Out:
#         Unnamed: 0                          name  age  time  \
# 0              675  Abdulla bin Ahmad Al Ghurair   67  2013
# 1              676  Abdulla bin Ahmad Al Ghurair   67  2013
# 2              677  Abdulla bin Ahmad Al Ghurair   67  2013
# 3              678  Abdulla bin Ahmad Al Ghurair   67  2013
# 4              679  Abdulla bin Ahmad Al Ghurair   67  2013
# ...            ...                           ...  ...   ...
# 352364      358313            Zygmunt Solorz-Zak   65  2022
# 352365      358314            Zygmunt Solorz-Zak   65  2022
# 352366      358315            Zygmunt Solorz-Zak   65  2022
# 352367      358316            Zygmunt Solorz-Zak   65  2022
# 352368      358317            Zygmunt Solorz-Zak   65  2022
#
#                 main_industry countries  annual_income  daily_income  \
# 0                 Diversified       are       95604000        261928
# 1                 Diversified       are       95604000        399254
# ...

# %%
data_set
#main dataset remains same if we change them in python
# Out:
#         Unnamed: 0                          name   last_name  age gender  \
# 0              675  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 1              676  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 2              677  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 3              678  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 4              679  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# ...            ...                           ...         ...  ...    ...
# 352364      358313            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352365      358314            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352366      358315            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352367      358316            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352368      358317            Zygmunt Solorz-Zak  Solorz-Zak   65      M
#
#         time           permanent_country         company  \
# ...

# %%
str='gnanendra'

# %%
str.replace('gnanendra','lalu')
#example for that there will be no change in real data
# Out:
# 'lalu'

# %%
str.replace('a','anna')
# Out:
# 'gnannanendranna'

# %%
str
# Out:
# 'gnanendra'

# %%
m=data_set['age'].mean()
#to find the mean in dataset given

# %%
m
# Out:
# 72.13032644755924

# %%
mo=data_set['age'].mode()
#to find the mode in dataset given

# %%
mo
# Out:
# 0    72
# Name: age, dtype: int64

# %%
me=data_set['age'].median()
#to find the median in dataset given

# %%
me
# Out:
# 72.0

# %%
v=data_set['age'].var()
#to find the variance in dataset given

# %%
v
# Out:
# 175.24318899150396

# %%
data_set['age'].fillna(value=mo)
#to find the fill the missing values with mode in dataset given
# Out:
# 0         67
# 1         67
# 2         67
# 3         67
# 4         67
#           ..
# 352364    65
# 352365    65
# 352366    65
# 352367    65
# 352368    65
# Name: age, Length: 352369, dtype: int64

# %%
data_set=pd.read_excel('stress.xlsx')
#to read the excel sheet containing dataset

# %%
m=data_set['age'].mean()

# %%
m
# Out:
# 19.2

# %%
data_set['age'].fillna(value=m)
# Out:
# 0    19
# 1    20
# 2    19
# 3    20
# 4    18
# Name: age, dtype: int64

# %%
data_set['stress of exams'].fillna(value=100)
# Out:
# 0      1.0
# 1    100.0
# 2      1.0
# 3      0.0
# 4      1.0
# Name: stress of exams, dtype: float64

# %%
m=data_set['stress of exams'].median()

# %%
m
# Out:
# 1.0

# %%
data_set['stress of exams'].fillna(value=m)
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    0.0
# 4    1.0
# Name: stress of exams, dtype: float64

# %%
data_set.tail()
#to print last 4 rows
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 data_set.tail()
#
# NameError: name 'data_set' is not defined
